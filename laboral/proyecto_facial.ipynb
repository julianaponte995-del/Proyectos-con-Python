# %%
import face_recognition
import cv2
import numpy as np
import json
from datetime import datetime
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import face_recognition
#       2 import cv2
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
# 1. Configuración de las herramientas de MediaPipe
configuracion_rostro = mp.solutions.face_mesh
# Creamos el objeto que detectará la malla facial
detector = configuracion_rostro.FaceMesh(
    static_image_mode=True, 
    max_num_faces=1, 
    min_detection_confidence=0.5
)
dibujo = mp.solutions.drawing_utils
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 1. Configuración de las herramientas de MediaPipe
# ----> 2 configuracion_rostro = mp.solutions.face_mesh
#       3 # Creamos el objeto que detectará la malla facial
#       4 detector = configuracion_rostro.FaceMesh(
#       5     static_image_mode=True,
#       6     max_num_faces=1,
#       7     min_detection_confidence=0.5
#       8 )
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
# !pip install jupyter face-recognition opencv-python numpy pillow matplotlib
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached dlib-20.0.0.tar.gz (3.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
# Failed to build dlib
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [41 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#
# ...
#
#                      CMake is not installed on your system!
#
# ...

# %%
# Instalar CMake
# !pip install cmake
